# %% [markdown]
# # Hallo!
# Herzlich Willkommen. Ich bin das allwissende Orakel, dass dir hilft heute eine Entscheidung zu treffen.

# %%
#Import
from ipywidgets import interact, Dropdown, Checkbox
import ipywidgets as widgets
from time import sleep
#Klasse Alternativantwort: Erstellt eine alternative Antworten, wenn gewünscht.
class Alternative:
    def __init__(self, kal, flach, fact):
        self.Kalenderspruch=kal
        self.Flachwitz=flach
        self.Funfact=fact
        
Alt1=Alternative("Es ist nicht von Bedeutung, wie langsam du gehst, solange du nicht stehenbleibst.","Was passiert, wenn zwei Krokodile sich einigen? Ein Krokodeal.","Wusstest du dass manche Schildkröten durch ihr Hinterteil atmen können?")
Alt2=Alternative("Wege entstehen dadurch, dass man sie geht.","Was ist glücklich und stinkt? Ein Gefurztagskind.","Wusstest du dass die Synchronsprecher von Minnie und Mickey Mouse\n\t\tim echten Leben geheiratet haben?")
Alt3=Alternative("Nichts auf der Welt ist so mächtig wie eine Idee, deren Zeit gekommen ist.","Was ist ein Keks unter einem Baum? Ein schattiges Plätzchen.","Wusstest du dass man in Norwegen im Jahr 2008 einen Pinguin zum Ritter ernannt hat?")
Alt4=Alternative("Der beste Weg etwas zu erreichen ist einfach anzufangen.","Was essen Autos am liebsten? Parkplätzchen.","Wusstest du, dass Schafe traurige und fröhliche Gesichter unterscheiden können\n\t\tund sich eher glücklich aussehenden Menschen nähern?")

# %%
#Start
#Name
Name = input("Wie ist dein Name?\n")
sleep (1)
print("\nHallo",Name,"! Schön dich kennen zu lernen!\n")
#Frage
sleep (2)
print ("Welche Frage liegt dir auf dem Herzen?")
sleep (2)
Frage = input ("Deine Frage:")
Frage = Frage
print ("\nDas ist eine gute Frage..")
sleep (3)
print ("Lass mich mal überlegen.\n")
#Alter
sleep (3)
print ("Um dir eine genaue Antwort geben zu können,\nmuss ich noch dein Alter wissen.\n")
sleep(3)
Alter = input ("Dein Alter:\n")
print ("\nDu bist also", Alter, "Jahre alt.\n")
sleep (3)
print ("Interessant..\n")
#Bedingung Alter
if int(Alter)<15:
    sleep(2)
    print("Du bist ja ganz schön jung.\nVielleicht fragst du lieber deine Eltern nach einem Ratschlag.\nDenkst du nicht?\n")
    sleep (2)
else:
    sleep(2)
    print ("Ich denke du bist alt genug, deine eigenen Entscheidungen zu treffen.\nDenkst du nicht?\n")
#Input weitermachen oder nicht
sleep(3)
print ("Antwortmöglchkeiten:\n")
print ("1. Ja da hast du Recht, allwissendes Orakel!\n")
print ("2. Nein ich möchte lieber dich fragen, oh allmächtiges Orakel!\n")
sleep(3)
AntwortUser=input("Tippe eine der Antwortmöglichkeiten ein:\n")
if AntwortUser== "Ja da hast du Recht, allwissendes Orakel!":
    sleep(1)
    print("\nVielen Dank für nichts!\nDann hättest du mich ja gar nicht erst belästigen müssen!\n")
    sleep(3)
    print("Das Mindeste, was du jetzt tun kannst,\nist mich wenigstens noch ein bisschen weiter zu bespaßen.\n")
elif AntwortUser=="Nein ich möchte lieber dich fragen, oh allmächtiges Orakel!":
    sleep(1)
    print("Besser ist es! Ich weiß sowieso alles am besten!\n")
else:
    sleep(1)
    print("Kannst du keine Anweisungen befolgen?\nDu solltest eine der Antwortmöglichkeiten eintippen!\n")
    sleep(2)
    print("Ohje.. Ich sehe schon warum du mich um Hilfe bittest.\n")
#Weiter mit Sternzeichen
sleep(3)
print ("Also lass uns weiter machen!\n")
sleep(3)
print("Egal ob du daran glaubst oder nicht,\naufgrund deines Sternzeichens, weiß ich\ngleich sehr viel mehr über dich.\n")
sleep(5)
print("In Kombination mit deiner Lieblingszahl, gibt es\nmir eine gute Grundlage die richtige Antwort\nauf deine Frage zu finden.\n")
sleep (5)
print("Also scheu dich nicht und wähle hier dein Sternzeichen aus\nund verrate mir deine Lieblingszahl:\n")
sleep(2)
#Sternzeichenloop
def SternzeichenLoop (Sternzeichen):
    ergebnis = ""
    if (Sternzeichen):
        ergebnis = "Bist du dir etwa unsicher oder warum schaust du hier nochmal hin?"
    else:
        ergebnis="Als ob ich es mir nicht schon denken kann, welches Sternzeichen du hast."
    return ergebnis
interact(SternzeichenLoop, Sternzeichen=Dropdown (value=None, options=('Dummkopf','Steinbock','Wassermann','Fische','Widder','Stier','Zwillinge','Krebs','Löwe','Jungfrau','Waage','Skorpion','Schütze')))
#Lieblingszahl
Lieblingszahl=input ("Was ist deine Lieblingszahl?\n")
sleep(2)
print("Deine Lieblingszahl ist also",Lieblingszahl,".\nDiese Kombination aus Sternzeichen und Lieblingszahl.. Huiuiui..\n")
sleep(4)
print(Name,", ich fange an dich zu mögen.\n")
sleep(3)
print("Sooooooooo...\nIch fokussiere mich auf die bestmögliche Antwort auf deine Frage.\n")
sleep(3)
print("Ich überlege...")
sleep(2)
print("Ich überlege...")
sleep(2)
print("Ich überlege...\n")
sleep(2)
#import random answer
import random
Antwort = ['Ja','Nein','Vielleicht','Dein Handeln wird die Dinge besser machen','Ist der Himmel blau?','Du solltest nicht darauf setzen','Befolge den Rat eines Fachmanns','Konzentriere dich auf dein Privatleben','Sicher','Es lässt sich nicht vorhersagen','Mit Sicherheit nicht','Geh es mit spielerischer Neugierde an','Warte besser','Behalte es für dich','Es könnte zu überraschenden Ergebnissen führen','Die Antwort erhältst du auf andere Art und Weise','Du wirst dich anpassen müssen','Es wird dir Glück bringen','Hab Geduld','Du wirst alles erfahren, was du wissen musst','Es steht in wichtigem Zusammenhang mit anderen Situationen','Sieh zu, was passiert','Du wirst froh sein, dass du es getan hast','Lass es dir schriftlich geben','Im Moment ungünstig','Wenn du tust, was dir gesagt wird','Verlang im Moment nicht mehr','Meide die naheliegende Lösung','Du wirst das letzte Wort behalten','Geh es langsam an','Die beste Lösung mag nicht die offensichtlichste sein','Bleib flexibel','Das hast du nicht in der Hand','Vorausgesetzt du bedankst dich dafür','Genieße die Erfahrung','Achte auf die Details','Pass auf, was du tust','Zögere nicht','Es ist ein guter Zeitpunkt, einen neuen Plan zu machen','Mach weiter','Die Umstände werden sich schnell ändern','Lass dich nicht von deinen Emotionen leiten','Ändere deinen Blickwinkel','Es ist von Bedeutung','Setze neue Prioritäten','Mach eine Liste mit dem, was dagegen spricht','Warte nicht','Du wirst es nicht vergessen','Du wirst es regeln','Folge deinen Verpflichtungen','Kümmere dich später darum','Mache eine Liste mit Gründen, die dagegen sprechen','Akzeptiere eine Änderung deiner Routine','Du musst die Initiative ergreifen','Du musst einen Kompromiss eingehen','Du brauchst mehr Informationen','Halte dich an deinen ersten Eindruck','Springe über deinen eigenen Schatten','Du solltest dich besser auf deine Arbeit konzentrieren','Es wird ein Vergnügen werden','Sei großzügiger','Du kannst deine Hand dafür ins Feuer legen','Bringe zuerst etwas anderes zu Ende','Du wirst möglicherweise Widerstand spüren','Du siehst den Wald vor lauter Bäumen nicht','Es ist ein beträchtlicher Aufwand nötig','Mach zuerst eine Pause','Die Gelegenheit wird sich so schnell nicht noch einmal ergeben','Es ist nicht ratsam','Warte auf ein besseres Angebot','Bring es bald in Ordnung','Ja, aber versuche nicht, es zu erzwingen','Verschaffe dir einen besseren Eindruck','Versuche es','Jetzt kannst du es','Tu nicht zu viel des Guten','Es wird dir Kraft geben','Es wird ein teures Vergnügen werden','Es wird die Dinge mit Sicherheit interessant machen','Geh die Sache nüchtern an','Spar dir deine Energie','Du musst möglicherweise andere Dinge sein lassen','Mach dir keine Sorgen','Sei auf Überraschungen gefasst','Es ist nicht von Bedeutung','Erzähle jemandem was es dir bedeutet','Was du auch tust, das Ergebnis wird Bestand haben','Sei unvoreingenommen','Es ist die Mühe wert','Hindernisse müssen überwunden werden','In diesem Zusammenhang können Probleme auftauchen','Wenn du Unterstützung erhältst, wird dein Vorgehen von Erfolg gekrönt sein','Zusammenarbeit heißt das Schlüsselwort','Übernimm die Verantwortung','Es kann nicht daneben gehen','Du musst jetzt handeln','Halte dich an die Regeln','Beharrlichkeit wird sich bezahlt machen','du wirst nicht enttäuscht sein','Führe dein Vorhaben durch','Lass dir mehr Zeit für eine Entscheidung','Übersieh das Offensichtliche nicht','Wenn du dich nicht widersetzt','Es lohnt sich nicht, darum zu kämpfen','Vergiss nicht deinen Spaß zu haben','Zweifle nicht daran','Ein großes Engagement wird gute Resultate erzielen','Versuche es mit einer unkonventionellen Lösung','Nicht, wenn du allein bist','Missgeschicke sind sehr wahrscheinlich','Dränge auf ein Ende der Debatte','Mach dir klar, dass zu viele Wahlmöglichkeiten genauso schwierig sind, wie zu wenige','Hör genau hin, dann wirst du es wissen','Die Antwort liegt vor deiner Haustüre','Lach darüber','Andere werden von deiner Entscheidung abhängig sein','Lass es los','Das wäre Geldverschwendung','Gib alles, was du hast','Es ist dir eigentlich egal','Du musst dir andere Möglichkeiten überlegen','Heute in einem Jahr ist es egal','Verschwende deine Zeit nicht','Tu so, als sei es schon so weit','Es wird notwendig sein, Prioritäten zu setzen','Benutze deine Phantasie','Es wird hervorragend werden','Um die beste Entscheidung zu ermöglichen, bleibe gelassen','Warte','Du wirst es bereuen','Natürlich','Trau deiner Intuition','Frag deinen Vater','Frag deine Mutter','Niemals','Vielleicht wenn du älter bist','Frage später noch einmal','Tu es','Mach dich nicht lächerlich','Es gibt gute Gründe, optimistisch zu sein','Du musst','Es ist Zeit für dich zu gehen','Du wirst enttäuscht sein']
def selectRandom(Antwort):
    return random.choice(Antwort)
print("Du hast gefragt:\n\t",Frage)
print("Ich sage:\n\t",selectRandom(Antwort))

#Möchtest du eine alternative Antwort?
sleep(5)
print("\nJa, doch mit dieser Antwort habe ich meiner Meinung nach voll ins Schwarze getroffen.")
sleep(2)
print("\nGefällt dir meine Antwort?")
sleep(2)
Antwort=input()
ListeJa=["Ja", "Yes", "J"]
ListeNein=["Nein","No","N"]
if Antwort=ListeJa:
    print("Super! Ich finde auch dass es eine tolle Antwort auf deine Frage ist.\nWeil wir uns so gut verstanden haben, hab ich noch ein Überraschungs-Türchen für dich.\n")
elif Antwort=ListeNein:
    print("Warum hab ich mir das bei dir nicht schon gedacht..\nWeil ich mich gerade großzügig fühle,\nkannst du dir hier eins von drei Trost-Türchen aussuchen.\n")
else:
    print("Ein Ja oder Nein hätte es getan.\nAuch wenn du es eigentlich nicht verdient hättest, bin ich immer für Gleichberechtigung.\nDeshalb darfst du dir im folgenden Abschnitt noch eins von drei Überrschungs-Türchen aussuchen.\n") 
    #Input welches Türchen
sleep(4)     
AlternativeInput=input ("1, 2 oder 3\nWas ist denn das für'n Geschrei?\n1, 2 oder 3\nOkay ich bin mit dabei!\n1, 2 oder 3\nUnd wer das meiste weiß,\nder kriegt am Ende dann den Preis!\nOkay ich geb's zu, das passt nicht zu hundert Prozent, hat sich hier aber angeboten.\nAlso jetzt bis du dran: 1, 2 oder 3?\n")
if int(AlternativeInput)<2:
    sleep(2)
    print("\nHier habe ich einen Flachwitz für dich:\n\t\t\t",Alt1.Flachwitz)
    sleep(4)
    print("\nObendrauf noch einen motivierenden Kalenderspruch:\n\t\t\t",Alt1.Kalenderspruch)
    sleep(4)
    print("\nWenn das alles nichts gebracht hat, dann hab ich wenigstens noch einen Funfact für dich,\nder hoffentlich für ein Lächeln sorgt:\n\t\t\t",Alt1.Funfact)
elif int(AlternativeInput)<3:
    sleep(2)
    print("\nHier habe ich einen Flachwitz für dich:\n\t\t\t",Alt2.Flachwitz)
    sleep(4)
    print("\nObendrauf noch einen motivierenden Kalenderspruch:\n\t\t\t",Alt2.Kalenderspruch)
    sleep(4)
    print("\nWenn das alles nichts gebracht hat, dann hab ich wenigstens noch einen Funfact für dich,\nder hoffentlich für ein Lächeln sorgt:\n\t\t\t",Alt2.Funfact)
elif int(AlternativeInput)<4:
    sleep(2)
    print("\nHier habe ich einen Flachwitz für dich:\n\t\t\t",Alt3.Flachwitz)
    sleep(4)
    print("\nObendrauf noch einen motivierenden Kalenderspruch:\n\t\t\t",Alt3.Kalenderspruch)
    sleep(4)
    print("\nWenn das alles nichts gebracht hat, dann hab ich wenigstens noch einen Funfact für dich,\nder hoffentlich für ein Lächeln sorgt:\n\t\t\t",Alt3.Funfact)
else:
    sleep(2)
    print("\nDu bist echt ein Fall für sich..\nNicht mal eine Zahl kannst du bei Aufforderung richtig eingeben.\nWeil ich dich trotzdem irgendwie mag,\nbekommst du das Türchen für ganz besondere Menschen.")  
    sleep(4)
    print("\nHier habe ich einen Flachwitz für dich:\n\t\t\t",Alt4.Flachwitz)
    sleep(4)
    print("\nObendrauf noch einen motivierenden Kalenderspruch:\n\t\t\t",Alt4.Kalenderspruch)
    sleep(4)
    print("\nWenn das alles nichts gebracht hat, dann hab ich wenigstens noch einen Funfact für dich,\nder hoffentlich für ein Lächeln sorgt:\n\t\t\t",Alt4.Funfact)
sleep(10)
#Verabschiedung
print("So,",Name,"\nIch hoffe ich konnte dir weiterhelfen oder dir zumindest einen\nschönen Zeitvertreib bieten.\n\nMir hat es auf jeden Fall Spaß gemacht und ich hoffe du \nkommst mit deiner nächsten Frage auch wieder zu mir.\n\nIch bin hier und warte auf dich.\nFür immer.\n")
sleep(6)
#Sinnloser Button
from IPython.display import display
button = widgets.Button(description="Sinnloser Knopf.")
output = widgets.Output()
display(button, output)
def on_button_clicked(b):
    with output:
        print("Ich habe keinen Sinn.")
button.on_click(on_button_clicked)
# Out:
# Wie ist dein Name?
# Dinah
#
# Hallo Dinah ! Schön dich kennen zu lernen!
#
# Welche Frage liegt dir auf dem Herzen?
# Deine Frage:d
#
# Das ist eine gute Frage..
# Lass mich mal überlegen.
#
# Um dir eine genaue Antwort geben zu können,
# muss ich noch dein Alter wissen.
#
# Dein Alter:
# 27
#
# Du bist also 27 Jahre alt.
#
# Interessant..
#
# Ich denke du bist alt genug, deine eigenen Entscheidungen zu treffen.
# Denkst du nicht?
#
# Antwortmöglchkeiten:
#
# 1. Ja da hast du Recht, allwissendes Orakel!
#
# 2. Nein ich möchte lieber dich fragen, oh allmächtiges Orakel!
#
# Tippe eine der Antwortmöglichkeiten ein:
# Ja
# Kannst du keine Anweisungen befolgen?
# Du solltest eine der Antwortmöglichkeiten eintippen!
#
# Ohje.. Ich sehe schon warum du mich um Hilfe bittest.
#
# Also lass uns weiter machen!
#
# Egal ob du daran glaubst oder nicht,
# aufgrund deines Sternzeichens, weiß ich
# gleich sehr viel mehr über dich.
#
# In Kombination mit deiner Lieblingszahl, gibt es
# mir eine gute Grundlage die richtige Antwort
# auf deine Frage zu finden.
#
# Also scheu dich nicht und wähle hier dein Sternzeichen aus
# und verrate mir deine Lieblingszahl:
# interactive(children=(Dropdown(description='Sternzeichen', options=('Dummkopf', 'Steinbock', 'Wassermann', 'Fi…
# Was ist deine Lieblingszahl?
# 10
# Deine Lieblingszahl ist also 10 .
# Diese Kombination aus Sternzeichen und Lieblingszahl.. Huiuiui..
#
# Dinah , ich fange an dich zu mögen.
#
# Sooooooooo...
# Ich fokussiere mich auf die bestmögliche Antwort auf deine Frage.
#
# Ich überlege...
# Ich überlege...
# Ich überlege...
#
# Du hast gefragt:
# 	 d
# Ich sage:
# 	 Niemals
# Gefällt dir meine Antwort?
# interactive(children=(Checkbox(value=False, description='Nein!'), Checkbox(value=False, description='Ja!'), Ou…
# 1, 2 oder 3
# Was ist denn das für'n Geschrei?
# 1, 2 oder 3
# Okay ich bin mit dabei!
# 1, 2 oder 3
# Und wer das meiste weiß,
# der kriegt am Ende dann den Preis!
# Okay ich geb's zu, das passt nicht zu hundert Prozent, hat sich hier aber angeboten.
# Also jetzt bis du dran: 1, 2 oder 3?
# 1
#
# Hier habe ich einen Flachwitz für dich:
# 			 Was passiert, wenn zwei Krokodile sich einigen? Ein Krokodeal.
#
# Obendrauf noch einen motivierenden Kalenderspruch:
# 			 Es ist nicht von Bedeutung, wie langsam du gehst, solange du nicht stehenbleibst.
#
# Wenn das alles nichts gebracht hat, dann hab ich wenigstens noch einen Funfact für dich,
# der hoffentlich für ein Lächeln sorgt:
# 		 Wusstest du dass manche Schildkröten durch ihr Hinterteil atmen können?
# So, Dinah .
# Ich hoffe ich konnte dir weiterhelfen oder dir zumindest einen
# schönen Zeitvertreib bieten.
# Mir hat es auf jeden Fall Spaß gemacht und ich hoffe du
# kommst mit deiner nächsten Frage auch wieder zu mir.
# Ich bin hier und warte auf dich.
# Für immer.
# Button(description='Sinnloser Knopf.', style=ButtonStyle())
# Output()

# %%
Antwort=input()
ListeJa=["Ja", "Yes", "J"]
ListeNein=["Nein","No","N"]
if Antwort==:
    print("Super! Ich finde auch dass es eine tolle Antwort auf deine Frage ist.\nWeil wir uns so gut verstanden haben, hab ich noch ein Überraschungs-Türchen für dich.\n")
elif Antwort==:
    print("Warum hab ich mir das bei dir nicht schon gedacht..\nWeil ich mich gerade großzügig fühle,\nkannst du dir hier eins von drei Trost-Türchen aussuchen.\n")
else:
    print("Ein Ja oder Nein hätte es getan.\nAuch wenn du es eigentlich nicht verdient hättest, ist mein Vorsatz, netter zu sein.\nDeshalb darfst du dir im folgenden Abschnitt noch eins von drei Türchen mit einer Überraschung aussuchen.\n")
# Out:
# Nein
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-16eb56d08424> in <module>
#       2 ListeJa=["Ja", "Yes", "J"]
#       3 ListeNein=["Nein","No","N"]
# ----> 4 if Antwort==value(ListeNein):
#       5     print("Super! Ich finde auch dass es eine tolle Antwort auf deine Frage ist.\nWeil wir uns so gut verstanden haben, hab ich noch ein Überraschungs-Türchen für dich.\n")
#       6 elif Antwort==value(ListeJa):
#
# NameError: name 'value' is not defined

# %%
#Radiobuttons
sleep(2)
print("Gefällt dir meine Antwort?\n")
radio = widgets.RadioButtons(options=['Ja!', 'Nein!'], layout={'width': 'max-content'}, value='Ja!' )
widgets.Box(
    [widgets.Label(value='Gefällt dir die Antwort?'),
    radio
    ] )
text = ''
sleep(2)
display(radio)
sleep(4)
def eval(a):
    if  a == 'Nein!':
        print ('Warum hab ich mir das bei dir nicht schon gedacht..\nWeil ich mich gerade großzügig fühle,\nkannst du dir hier eins von drei Trost-Türchen aussuchen.\n')
    else:
        print('Super! Ich finde auch dass es eine tolle Antwort auf deine Frage ist.\nWeil wir uns so gut verstanden haben, hab ich noch ein Überraschungs-Türchen für dich.\n')
out = widgets.interactive_output(eval, {'a': radio})
sleep(4)
display(out)
#Radiobutton Loop
def RadiobuttonLoop (Nein,Ja):
    ergebnis = ""
    if (Nein):
        ergebnis = "Warum hab ich mir das bei dir nicht schon gedacht..Weil ich mich gerade großzügig fühle,kannst du dir hier eins von drei Trost-Türchen aussuchen."
    elif(Ja):
        ergebnis="Super! Ich finde auch dass es eine tolle Antwort auf deine Frage ist.Weil wir uns so gut verstanden haben, hab ich noch ein Überraschungs-Türchen für dich."
    else:
        ergebnis="Ich will deine ehrliche Meinung wissen, auch wenn sie mir wahrscheinlich nicht gefallen wird."
    return ergebnis
interact(RadiobuttonLoop,Nein=Checkbox(value=None, description='Nein!'), Ja=Checkbox(value=None, description='Ja!'))

# %%
#Weiter mit Sternzeichen
sleep(2)
print ("Also lass uns weiter machen!")
sleep(2)
print("Egal ob du daran glaubst oder nicht, aufgrund deines Sternzeichens, weiß ich gleich sehr viel mehr über dich.")
sleep(3)
print("In Kombination mit deiner Lieblingszahl, gibt es mir eine gute Grundlage die richtige Antwort auf deine Frage zu finden.")
sleep (3)
print("Also scheu dich nicht und wähle hier dein Sternzeichen aus und verrate mir deine Lieblingszahl:")
sleep(1)
#Sternzeichenloop
def SternzeichenLoop (Sternzeichen):
    ergebnis = ""
    if (Sternzeichen):
        ergebnis = "Ahh.. Das dachte ich mir ja schon fast."
    else:
        ergebnis="Komm schon trau dich."
    return ergebnis
interact(SternzeichenLoop, Sternzeichen=Dropdown (value=None, options=('Dummkopf','Steinbock','Wassermann','Fische','Widder','Stier','Zwillinge','Krebs','Löwe','Jungfrau','Waage','Skorpion','Schütze')))
sleep(1)
Lieblingszahl=input ("Was ist deine Lieblingszahl?")
sleep(2)
print("Deine Lieblingszahl ist also",Lieblingszahl,". Diese Kombination aus Sternzeichen und Lieblingszahl.. Huiuiui..")
sleep(3)
print(Name,", ich fange an dich zu mögen.")
# Out:
# Also lass uns weiter machen!
# Egal ob du daran glaubst oder nicht, aufgrund deines Sternzeichens, weiß ich gleich sehr viel mehr über dich.
# In Kombination mit deiner Lieblingszahl, gibt es mir eine gute Grundlage die richtige Antwort auf deine Frage zu finden.
# Also scheu dich nicht und wähle hier dein Sternzeichen aus und verrate mir deine Lieblingszahl:
# interactive(children=(Dropdown(description='Sternzeichen', options=('Dummkopf', 'Steinbock', 'Wassermann', 'Fi…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e15d47161acd> in <module>
#      19 interact(SternzeichenLoop, Sternzeichen=Dropdown (value=None, options=('Dummkopf','Steinbock','Wassermann','Fische','Widder','Stier','Zwillinge','Krebs','Löwe','Jungfrau','Waage','Skorpion','Schütze')))
#      20 sleep(1)
# ---> 21 Lieblingszahl=input ("Was ist deine Lieblingszahl?")
#      22 sleep(2)
#      23 print("Deine Lieblingszahl ist also",Lieblingszahl,". Diese Kombination aus Sternzeichen und Lieblingszahl.. Huiuiui..")
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Aus dem Unterricht

# %%
#umständlicher Loop
def Sternzeichen (Dummkopf,Steinbock,Wassermann,Fische,Widder,Stier,Zwillinge,Krebs,Löwe,Jungfrau,Waage,Skorpion,Schütze):
    ergebnis = ""
    if (Dummkopf):
        sleep(3)
        ergebnis = "Dummkopf"
    elif (Steinbock):
        sleep(3)
        ergebnis="Steinbock"
    elif (Wassermann):
        sleep(3)
        ergebnis= "Wassermann"
    elif (Fische):
        sleep(3)
        ergebnis="Fische"
    elif (Widder):
        sleep(3)
        ergebnis="Widder"
    elif (Stier):
        sleep(3)
        ergebnis="Stier"
    elif (Zwillinge):
        sleep(3)
        ergebnis="Zwillinge"
    elif (Krebs):
        sleep(3)
        ergebnis="Krebs"
    elif (Löwe):
        sleep(3)
        ergebnis="Löwe"
    elif (Jungfrau):
        sleep(3)
        ergebnis="Jungfrau"
    elif (Waage):
        sleep(3)
        ergebnis="Waage"
    elif (Skorpion):
        sleep(3)
        ergebnis="Skorpion"
    elif (Schütze):
        sleep(3)
        ergebnis="Schütze"
    else:
        sleep(4)
        ergebnis="Ich warte nicht gerne..."
    return (Dummkopf or Steinbock or Wassermann or Fische or Widder or Stier or Zwillinge or Krebs or Löwe or Jungfrau or Waage or Skorpion or Schütze)

# %%
interact(Sternzeichen, Dummkopf=Dropdown (value=None, options= ("Hallo","ne")),Steinbock=False,Wassermann=False,Fische=False,Widder=False,Stier=False,Zwillinge=False,Krebs=False,Löwe=False,Jungfrau=False,Waage=False,Skorpion=False,Schütze=False)

# %%
#Sternzeichenloop Versuch 1
def SternzeichenLoop (Sternzeichen):
    ergebnis = ""
    if (Sternzeichen):
        ergebnis = "Ahh.. Das dachte ich mir ja schon fast."
    else:
        sleep(4)
        ergebnis="Ich warte nicht gerne!"
    return ergebnis
interact(SternzeichenLoop, Sternzeichen=Dropdown (value=None, options= ('Dummkopf','Steinbock','Wassermann','Fische','Widder','Stier','Zwillinge','Krebs','Löwe','Jungfrau','Waage','Skorpion','Schütze')))

# %%
#Loop Methode erste
def ErsterLoop (Nein,Ja):
    ergebnis = ""
    if (Nein):
        sleep(1)
        ergebnis = "Besser ist es, ich weiß sowieso alles am besten."
    elif (Ja):
        sleep(1)
        ergebnis = "Vielen Dank für nichts! Dann hättest du mich ja gar nicht erst belästigen müssen!"
    else:
        ergebnis="Ich warte nicht gerne!"
    return ergebnis
interact(ErsterLoop,Nein=Checkbox(value=None, description="Nein, ich möchte lieber dich fragen, oh allmächtiges Orakel!"), Ja=Checkbox(value=None, description="Ja, da hast du Recht, allwissendes Orakel!"))
sleep(2)
print('')
print("Da wir das jetzt geklärt haben, kanns ja weiter gehen.")

# %%
#Input weitermachen oder nicht
print ("Antwortmöglchkeiten:")
print ("1. Ja da hast du Recht, allwissendes Orakel!")
print ("2. Nein ich möchte lieber dich fragen, oh allmächtiges Orakel!")
AntwortUser=input("Gebe eine der Antwortmöglichkeiten ein:  ")
if AntwortUser== "Ja da hast du Recht, allwissendes Orakel!":
    sleep(1)
    print("Vielen Dank für nichts! Dann hättest du mich ja gar nicht erst belästigen müssen!")
    sleep(2)
    print("Das Mindeste, was du jetzt tun kannst, ist mich wenigstens noch ein bisschen weiter zu bespaßen.")
elif AntwortUser=="Nein ich möchte lieber dich fragen, oh allmächtiges Orakel":
    sleep(1)
    print("Besser ist es! Ich weiß sowieso alles am besten!")
else:
    sleep(2)
    print("Kannst du keine Anweisungen befolgen? Du solltest eine der Antwortmöglichkeiten eingeben!")
    sleep(2)
    print("Ohje.. Ich sehe schon warum du mich um Hilfe bittest.")

# %% [markdown]
# # Für später gespeichert:

# %%
#Radiobuttons Gefällt dir die Antwort?
sleep(2)
radio = widgets.RadioButtons(options=['Wähle aus:','Ja!', 'Nein!'], layout={'width': 'max-content'}, value='Wähle aus:' )
widgets.Box(
    [widgets.Label(value='Gefällt dir die Antwort?'),
    radio
    ] )
text = ''
display(radio)
def eval(a):
    if  a == 'Nein!':
        print ('Warum hab ich mir das bei dir nicht schon gedacht..\nWeil ich mich gerade großzügig fühle,\nkannst du dir hier eins von drei Trost-Türchen aussuchen.')
    elif a=='Wähle aus:':
        print("")
    else:
        print('Super! Ich finde auch dass es eine tolle Antwort auf deine Frage ist.')
out = widgets.interactive_output(eval, {'a': radio})
display(out)
# Out:
# RadioButtons(layout=Layout(width='max-content'), options=('Wähle aus:', 'Ja!', 'Nein!'), value='Wähle aus:')
# Output()

# %%
#Dropdownmenü Sternzeichen alt
drop= widgets.Dropdown(
    options=['Dummkopf','Steinbock','Wassermann','Fische','Widder','Stier','Zwillinge','Krebs','Löwe','Jungfrau','Waage','Skorpion','Schütze'],
    value='Dummkopf',
    description='Sternzeichen')
display (drop)
def eval(b):
    if b == 'Dummkopf':
        sleep (4)
        print("Sternzeichen Dummkopf. Ja das ist wohl zutreffend..")
    elif b == 'Wähle aus..':
        sleep(4)
        print ('Ich warte nich gerne.')
    else:
        sleep(2)
        print ("Ahh..Das dachte ich mir ja schon fast.")
outb=widgets.interactive_output(eval,{'b': drop})
display (outb)

# %%
#import random answer
import random
Antwort = ['Ja','Nein','Vielleicht','Dein Handeln wird die Dinge besser machen','Ist der Himmel blau?','Du solltest nicht darauf setzen','Befolge den Rat eines Fachmanns','Konzentriere dich auf dein Privatleben','Sicher','Es lässt sich nicht vorhersagen','Mit Sicherheit nicht','Geh es mit spielerischer Neugierde an','Warte besser','Behalte es für dich','Es könnte zu überraschenden Ergebnissen führen','Die Antwort erhältst du auf andere Art und Weise','Du wirst dich anpassen müssen','Es wird dir Glück bringen','Hab Geduld','Du wirst alles erfahren, was du wissen musst','Es steht in wichtigem Zusammenhang mit anderen Situationen','Sieh zu, was passiert','Du wirst froh sein, dass du es getan hast','Lass es dir schriftlich geben','Im Moment ungünstig','Wenn du tust, was dir gesagt wird','Verlang im Moment nicht mehr','Meide die naheliegende Lösung','Du wirst das letzte Wort behalten','Geh es langsam an','Die beste Lösung mag nicht die offensichtlichste sein','Bleib flexibel','Das hast du nicht in der Hand','Vorausgesetzt du bedankst dich dafür','Genieße die Erfahrung','Achte auf die Details','Pass auf, was du tust','Zögere nicht','Es ist ein guter Zeitpunkt, einen neuen Plan zu machen','Mach weiter','Die Umstände werden sich schnell ändern','Lass dich nicht von deinen Emotionen leiten','Ändere deinen Blickwinkel','Es ist von Bedeutung','Setze neue Prioritäten','Mach eine Liste mit dem, was dagegen spricht','Warte nicht','Du wirst es nicht vergessen','Du wirst es regeln','Folge deinen Verpflichtungen','Kümmere dich später darum','Mache eine Liste mit Gründen, die dagegen sprechen','Akzeptiere eine Änderung deiner Routine','Du musst die Initiative ergreifen','Du musst einen Kompromiss eingehen','Du brauchst mehr Informationen','Halte dich an deinen ersten Eindruck','Springe über deinen eigenen Schatten','Du solltest dich besser auf deine Arbeit konzentrieren','Es wird ein Vergnügen werden','Sei großzügiger','Du kannst deine Hand dafür ins Feuer legen','Bringe zuerst etwas anderes zu Ende','Du wirst möglicherweise Widerstand spüren','Du siehst den Wald vor lauter Bäumen nicht','Es ist ein beträchtlicher Aufwand nötig','Mach zuerst eine Pause','Die Gelegenheit wird sich so schnell nicht noch einmal ergeben','Es ist nicht ratsam','Warte auf ein besseres Angebot','Bring es bald in Ordnung','Ja, aber versuche nicht, es zu erzwingen','Verschaffe dir einen besseren Eindruck','Versuche es','Jetzt kannst du es','Tu nicht zu viel des Guten','Es wird dir Kraft geben','Es wird ein teures Vergnügen werden','Es wird die Dinge mit Sicherheit interessant machen','Geh die Sache nüchtern an','Spar dir deine Energie','Du musst möglicherweise andere Dinge sein lassen','Mach dir keine Sorgen','Sei auf Überraschungen gefasst','Es ist nicht von Bedeutung','Erzähle jemandem was es dir bedeutet','Was du auch tust, das Ergebnis wird Bestand haben','Sei unvoreingenommen','Es ist die Mühe wert','Hindernisse müssen überwunden werden','In diesem Zusammenhang können Probleme auftauchen','Wenn du Unterstützung erhältst, wird dein Vorgehen von Erfolg gekrönt sein','Zusammenarbeit heißt das Schlüsselwort','Übernimm die Verantwortung','Es kann nicht daneben gehen','Du musst jetzt handeln','Halte dich an die Regeln','Beharrlichkeit wird sich bezahlt machen','du wirst nicht enttäuscht sein','Führe dein Vorhaben durch','Lass dir mehr Zeit für eine Entscheidung','Übersieh das Offensichtliche nicht','Wenn du dich nicht widersetzt','Es lohnt sich nicht, darum zu kämpfen','Vergiss nicht deinen Spaß zu haben','Zweifle nicht daran','Ein großes Engagement wird gute Resultate erzielen','Versuche es mit einer unkonventionellen Lösung','Nicht, wenn du allein bist','Missgeschicke sind sehr wahrscheinlich','Dränge auf ein Ende der Debatte','Mach dir klar, dass zu viele Wahlmöglichkeiten genauso schwierig sind, wie zu wenige','Hör genau hin, dann wirst du es wissen','Die Antwort liegt vor deiner Haustüre','Lach darüber','Andere werden von deiner Entscheidung abhängig sein','Lass es los','Das wäre Geldverschwendung','Gib alles, was du hast','Es ist dir eigentlich egal','Du musst dir andere Möglichkeiten überlegen','Heute in einem Jahr ist es egal','Verschwende deine Zeit nicht','Tu so, als sei es schon so weit','Es wird notwendig sein, Prioritäten zu setzen','Benutze deine Phantasie','Es wird hervorragend werden','Um die beste Entscheidung zu ermöglichen, bleibe gelassen','Warte','Du wirst es bereuen','Natürlich','Trau deiner Intuition','Frag deinen Vater','Frag deine Mutter','Niemals','Vielleicht wenn du älter bist','Frage später noch einmal','Tu es','Mach dich nicht lächerlich','Es gibt gute Gründe, optimistisch zu sein','Du musst','Es ist Zeit für dich zu gehen','Du wirst enttäuscht sein']
def selectRandom(Antwort):
    return random.choice(Antwort)
print("Du hast gefragt:",Frage)
print("Ich sage:",selectRandom(Antwort))
# Out:
# Du hast gefragt: Bin ich dumm?
# Ich sage: Du wirst das letzte Wort behalten

# %%
#Sinnloser Button
from IPython.display import display
button = widgets.Button(description="Sinnloser Knopf.")
output = widgets.Output()
display(button, output)
def on_button_clicked(b):
    with output:
        print("Ich habe keinen Sinn.")
button.on_click(on_button_clicked)

# %%
widgets.Dropdown(
    options=['Ja, da hast du Recht allwissendes Orakel!', 'Nein, ich möchte lieber dich fragen, oh allmächtiges Orakel!'],
    value='Nein, ich möchte lieber dich fragen, oh allmächtiges Orakel!',
    description='Was sagst du?')

# %%
widgets.DatePicker(
    description='Pick a Date',
    disabled=False
)

# %%
widgets.ColorPicker(
    concise=False,
    description='Pick a color',
    value='blue',
    disabled=False
)

# %%
AlternativeInput=input ("1, 2 oder 3\nWas ist denn das für'n Geschrei?\n1, 2 oder 3\nOkay ich bin mit dabei!\n1, 2 oder 3\nUnd wer das meiste weiß,\nder kriegt am Ende dann den Preis!\n1, 2 oder 3?\n")

#Klasse Alternativantwort: Erstellt eine alternative Antworten, wenn gewünscht.
class Alternative:
    def __init__(self, kal, flach, fact):
        self.Kalenderspruch=kal
        self.Flachwitz=flach
        self.Funfact=fact
        
Alt1=Alternative("Es ist nicht von Bedeutung, wie langsam du gehst, solange du nicht stehenbleibst.","Was passiert, wenn zwei Krokodile sich einigen? Ein Krokodeal.","Wusstest du dass manche Schildkröten durch ihr Hinterteil atmen können?")
Alt2=Alternative("Wege entstehen dadurch, dass man sie geht.","Was ist glücklich und stinkt? Ein Gefurztagskind.","Wusstest du dass die Synchronsprecher von Minnie und Mickey Mouse im echten Leben geheiratet haben?")
Alt3=Alternative("Nichts auf der Welt ist so mächtig wie eine Idee, deren Zeit gekommen ist.","Was ist ein Keks unter einem Baum? Ein schattiges Plätzchen.","Wusstest du dass man in Norwegen im Jahr 2008 einen Pinguin zum Ritter ernannt hat?")

if int(AlternativeInput)<2:
    print("Ein Flachwitz für dich:\n\t\t",Alt1.Flachwitz)
    print("Oder vielleicht ein klassischer Kalenderspruch:\n\t\t",Alt1.Kalenderspruch)
    print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t\t",Alt1.Funfact)
elif int(AlternativeInput)<3:
    print("Ein Flachwitz für dich:\n\t\t",Alt2.Flachwitz)
    print("Oder vielleicht ein klassischer Kalenderspruch:\n\t\t",Alt2.Kalenderspruch)
    print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t\t",Alt2.Funfact)
elif int(AlternativeInput)<4:
    print("Ein Flachwitz für dich:\n\t\t",Alt3.Flachwitz)
    print("Oder vielleicht ein klassischer Kalenderspruch:\n\t\t",Alt3.Kalenderspruch)
    print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t\t",Alt3.Funfact)
else:
    print("Auch wenn du selbst bei der letzten Eingabe wieder keine Anweisungen befolgen konnntest,\nhoffe ich, dass ich dich zumindest ein bisschen unterhalten konnte.")

# %%
def FunktionAlt(Alternative):
    if ("1"):
        print("Ein Flachwitz für dich:\n\t\t",Alt1.Flachwitz)
        print("Oder vielleicht ein klassischer Kalenderspruch:\n\t",Alt1.Kalenderspruch)
        print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t",Alt1.Funfact)
    elif ("2"):
        print("Ein Flachwitz für dich:\n\t",Alt2.Flachwitz)
        print("Oder vielleicht ein klassischer Kalenderspruch:\n\t",Alt2.Kalenderspruch)
        print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t",Alt2.Funfact)
    elif ("3"):
        print("Ein Flachwitz für dich:\n\t",Alt3.Flachwitz)
        print("Oder vielleicht ein klassischer Kalenderspruch:\n\t",Alt3.Kalenderspruch)
        print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t",Alt3.Funfact)
    else:
        print("Auch wenn du selbst bei der letzten Eingabe wieder keine Anweisungen befolgen konnntest,\nhoffe ich, dass ich dich zumindest ein bisschen unterhalten konnte.")

print(FunktionAlt)

# %%
sleep(2)
radio = widgets.RadioButtons(options=['Wähle aus:','Ja!', 'Nein!'], layout={'width': 'max-content'}, value='Wähle aus:' )
widgets.Box(
    [widgets.Label(value='Gefällt dir die Antwort?'),
    radio
    ] )
text = ''
display(radio)

def eval(a):
    if  a == 'Nein!':
        print ('Warum hab ich mir das bei dir nicht schon gedacht..\nWeil ich mich gerade großzügig fühle,\nkannst du dir hier eins von drei Trost-Türchen aussuchen.')
        #Input welches Türchen
        sleep(3)
        AlternativeInput=input ("1, 2 oder 3\nWas ist denn das für'n Geschrei?\n1, 2 oder 3\nOkay ich bin mit dabei!\n1, 2 oder 3\nUnd wer das meiste weiß,\nder kriegt am Ende dann den Preis!\nOkay ich geb's zu, das passt nicht zu hundert Prozent, hat sich hier aber angeboten.\n Also jetzt bis du dran: 1, 2 oder 3?\n")
            if int(AlternativeInput)<2:
                print("Ein Flachwitz für dich:\n\t\t",Alt1.Flachwitz)
                print("Oder vielleicht ein klassischer Kalenderspruch:\n\t\t",Alt1.Kalenderspruch)
                print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t\t",Alt1.Funfact)
            elif int(AlternativeInput)<3:
                print("Ein Flachwitz für dich:\n\t\t",Alt2.Flachwitz)
                print("Oder vielleicht ein klassischer Kalenderspruch:\n\t\t",Alt2.Kalenderspruch)
                print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t\t",Alt2.Funfact)
            elif int(AlternativeInput)<4:
                print("Ein Flachwitz für dich:\n\t\t",Alt3.Flachwitz)
                print("Oder vielleicht ein klassischer Kalenderspruch:\n\t\t",Alt3.Kalenderspruch)
                print("Wenn das alles nicht für gute Laune gesorgt hat, dann hab ich wenigstens noch einen schönen Funfact für dich:\n\t\t",Alt3.Funfact)
            else:
                print("Auch wenn du selbst bei der letzten Eingabe wieder keine Anweisungen befolgen konnntest,\nhoffe ich, dass ich dich zumindest ein bisschen unterhalten konnte.")
    elif a=='Wähle aus:':
        print("")
    else:
        print('Super! Ich finde auch dass es eine tolle Antwort auf deine Frage ist.')
# Out:
#   File "<ipython-input-10-dc26d10df730>", line 16
#     if int(AlternativeInput)<2:
#     ^
# IndentationError: unexpected indent

# %%
widgets.ToggleButtons(
    options=['Slow', 'Regular', 'Fast'],
    description='Speed:',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=['Description of slow', 'Description of regular', 'Description of fast'],
#     icons=['check'] * 3
)
# Out:
# ToggleButtons(description='Speed:', options=('Slow', 'Regular', 'Fast'), tooltips=('Description of slow', 'Des…

# %%
file = open("https://hub.gke2.mybinder.org/user/ha-nid-programming-process-i7xtl105/view/MemeWaiting.jpg")
image = file.read()
widgets.Image(
    value=image,
    format='jpg',
    width=300,
    height=400,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-4e45e71838f1> in <module>
# ----> 1 file = open("https://hub.gke2.mybinder.org/user/ha-nid-programming-process-i7xtl105/view/MemeWaiting.jpg")
#       2 image = file.read()
#       3 widgets.Image(
#       4     value=image,
#       5     format='jpg',
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://hub.gke2.mybinder.org/user/ha-nid-programming-process-i7xtl105/view/MemeWaiting.jpg'

# %%
from IPython.display import display, Image

display(Image('github.com/ha-nid/Programming-Process/main/MemeWaiting.jpg'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'github.com/ha-nid/Programming-Process/main/MemeWaiting.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'github.com/ha-nid/Programming-Process/main/MemeWaiting.jpg'

# %%
from IPython.display import display
from PIL import Image
import requests
from io import BytesIO

response = requests.get('https://github.com/ha-nid/Programming-Process/blob/main/MemeWaiting.jpg')
img = Image.open(BytesIO(response.content))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-98df5abf2c0a> in <module>
#       1 from IPython.display import display
# ----> 2 from PIL import Image
#       3 import requests
#       4 from io import BytesIO
#       5
#
# ModuleNotFoundError: No module named 'PIL'

# %%
def RadiobuttonLoop (Nein,Ja):
    ergebnis = ""
    if (Nein):
        ergebnis = "Warum hab ich mir das bei dir nicht schon gedacht..\nWeil ich mich gerade großzügig fühle,\nkannst du dir hier eins von drei Trost-Türchen aussuchen.\n'"
    elif(Ja):
        ergebnis="Super! Ich finde auch dass es eine tolle Antwort auf deine Frage ist.\nWeil wir uns so gut verstanden haben, hab ich noch ein Überraschungs-Türchen für dich.\n'"
    else:
        ergebnis="Ich will deine ehrliche Meinung wissen, auch wenn sie mir wahrscheinlich nicht gefallen wird."
    return ergebnis
interact(RadiobuttonLoop,Nein=Checkbox(value=None, description='Nein!'), Ja=Checkbox(value=None, description='Ja!'))
# Out:
# interactive(children=(Checkbox(value=False, description='Nein!'), Checkbox(value=False, description='Ja!'), Ou…
# <function __main__.RadiobuttonLoop(Nein, Ja)>
